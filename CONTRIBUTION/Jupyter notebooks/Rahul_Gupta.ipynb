# %% [markdown]
# # Part 1

# %% [markdown]
# ## Imports

# %%
# %config Completer.use_jedi = False

# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
import re
nltk.download('averaged_perceptron_tagger')
nltk.download('sentiwordnet')

# %% [markdown]
# ## Handling Dataset

# %% [markdown]
# Reading the dataset and adding new features

# %%
df= pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                         Data       Date     Time  \
# 0           0                 tuesdayvibes  7/14/2020  7:00:21
# 1           1                    realmeC11  7/14/2020  7:00:21
# 2           2                  KPSharmaOli  7/14/2020  7:00:21
# 3           3              RheaChakraborty  7/14/2020  7:00:21
# 4           4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...

# %% [markdown]
# Cleaning the tweet captions

# %%
# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

# Cleaning the text in the review column
df['Cleaned Tweetcaptions'] = df['tweetcaption'].apply(clean)
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...

# %% [markdown]
# Adding Parts of Speech (POS) for Vader analysis

# %%
# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist

df['POS tagged'] = df['Cleaned Tweetcaptions'].apply(token_stop_pos)
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                           POS tagged
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  [(shree, a), (problem, n), (people, n), (probl...
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...

# %% [markdown]
# Adding Lemma column

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos:
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

df['Lemma'] = df['POS tagged'].apply(lemmatize)
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                           POS tagged  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  [(shree, a), (problem, n), (people, n), (probl...
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...
#
#                                                Lemma
# 0    Love vacation vibe amaze beautiful cabo mexi...
# 1    Best Camera Smartphone k Please vote help re...
# 2    shree problem people problem Stupid Communis...
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...
# 4    stand Sunita Yadav Stop Transfer woman empow...

# %%
df.Data.nunique()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35266 entries, 0 to 35265
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    35266 non-null  int64
#  1   Data          35266 non-null  object
#  2   Date          35266 non-null  object
#  3   Time          35266 non-null  object
#  4   tweetcaption  35266 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# As we can see there are no null values

# %% [markdown]
# ## Building Functions

# %% [markdown]
# I have used three rule based analysis models:
# 1. <strong>VADER</strong> (Valence Aware Dictionary for Sentiment Reasoning): It is a model used for text sentiment analysis that is sensitive to both polarity (positive/negative) and intensity (strength) of emotion.
# 2. <strong>TextBlob</strong>: TextBlob returns polarity and subjectivity of a sentence. Polarity lies between [-1,1], -1 defines a negative sentiment and 1 defines a positive sentiment.
# 3. <strong>SentiWordNet</strong> :SentiWordNet is an opinion lexicon derived from the WordNet database where each term is
# associated with numerical scores indicating positive and negative sentiment information.

# %% [markdown]
# ##### VADER

# %%
sid = SentimentIntensityAnalyzer() #Vader Sentiment analyser

# %%
df['scores']=df['Lemma'].apply(lambda lemma: sid.polarity_scores(lemma)) #applying Vader analysis on Lemma
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                           POS tagged  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  [(shree, a), (problem, n), (people, n), (probl...
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  \
# 0          0.159         0.800
# 1          0.093         0.878
# 2          0.131         0.797
# 3          0.173         0.713
# 4          0.138         0.710
#
#                                               scores
# 0  {'neg': 0.059, 'neu': 0.742, 'pos': 0.199, 'co...
# 1  {'neg': 0.031, 'neu': 0.833, 'pos': 0.136, 'co...
# 2  {'neg': 0.123, 'neu': 0.689, 'pos': 0.188, 'co...
# 3  {'neg': 0.126, 'neu': 0.661, 'pos': 0.214, 'co...
# 4  {'neg': 0.213, 'neu': 0.586, 'pos': 0.201, 'co...

# %%
df['compound'] = df['scores'].apply(lambda score_dict: score_dict['compound'])
df['sentiment_type']=''
df.loc[df.compound>0,'sentiment_type']='POSITIVE'
df.loc[df.compound==0,'sentiment_type']='NEUTRAL'
df.loc[df.compound<0,'sentiment_type']='NEGATIVE'

# %%
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                           POS tagged  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  [(shree, a), (problem, n), (people, n), (probl...
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  \
# 0          0.159         0.800
# 1          0.093         0.878
# 2          0.131         0.797
# 3          0.173         0.713
# 4          0.138         0.710
#
#                                               scores  compound sentiment_type
# 0  {'neg': 0.059, 'neu': 0.742, 'pos': 0.199, 'co...    0.9747       POSITIVE
# 1  {'neg': 0.031, 'neu': 0.833, 'pos': 0.136, 'co...    0.9349       POSITIVE
# 2  {'neg': 0.123, 'neu': 0.689, 'pos': 0.188, 'co...    0.8522       POSITIVE
# 3  {'neg': 0.126, 'neu': 0.661, 'pos': 0.214, 'co...    0.9517       POSITIVE
# 4  {'neg': 0.213, 'neu': 0.586, 'pos': 0.201, 'co...    0.2023       POSITIVE

# %%
df['sentiment_type'].value_counts()
# Out:
# POSITIVE    27652
# NEGATIVE     7468
# NEUTRAL       146
# Name: sentiment_type, dtype: int64

# %% [markdown]
# #### TextBlob

# %%
from textblob import TextBlob

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity
  
 #Create a function to get the polarity
def getPolarity(text):
   return TextBlob(text).sentiment.polarity
  
 #Create two new columns ‘Subjectivity’ & ‘Polarity’
# df[‘TextBlob_Subjectivity’] =    df[‘tweet’].apply(getSubjectivity)
df ['TextBlob_Polarity'] = df["Lemma"].apply(getPolarity)
def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"
df["TextBlob_Analysis"] = df["TextBlob_Polarity"].apply(getAnalysis )

# %%
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                           POS tagged  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  [(shree, a), (problem, n), (people, n), (probl...
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  \
# 0          0.159         0.800
# 1          0.093         0.878
# 2          0.131         0.797
# 3          0.173         0.713
# 4          0.138         0.710
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.059, 'neu': 0.742, 'pos': 0.199, 'co...    0.9747       POSITIVE
# 1  {'neg': 0.031, 'neu': 0.833, 'pos': 0.136, 'co...    0.9349       POSITIVE
# 2  {'neg': 0.123, 'neu': 0.689, 'pos': 0.188, 'co...    0.8522       POSITIVE
# 3  {'neg': 0.126, 'neu': 0.661, 'pos': 0.214, 'co...    0.9517       POSITIVE
# 4  {'neg': 0.213, 'neu': 0.586, 'pos': 0.201, 'co...    0.2023       POSITIVE
#
#    TextBlob_Polarity TextBlob_Analysis
# 0           0.142695          Positive
# 1           0.200033          Positive
# 2           0.118750          Positive
# 3           0.142857          Positive
# 4           0.213228          Positive

# %% [markdown]
# comparing analysis of vader and TextBlob

# %%
print(df['sentiment_type'].value_counts())
print(df['TextBlob_Analysis'].value_counts())
# Out:
# POSITIVE    27652
# NEGATIVE     7468
# NEUTRAL       146
# Name: sentiment_type, dtype: int64
# Positive    29343
# Negative     5675
# Neutral       248
# Name: TextBlob_Analysis, dtype: int64

# %% [markdown]
# Here I tried to normalize the scores to come up with a new scoring system, however it turned out that it is not very useful so I dropped this idea

# %%
df.describe()
# Out:
#        NegativeScore  positiveScore  neutralScore      compound  \
# count   35266.000000   35266.000000  35266.000000  35266.000000
# mean        0.067057       0.149762      0.783177      0.544859
# std         0.057859       0.082912      0.080023      0.712728
# min         0.000000       0.000000      0.305000     -0.999400
# 25%         0.021000       0.091000      0.735000      0.456700
# 50%         0.054000       0.134000      0.788000      0.953100
# 75%         0.101000       0.192000      0.837000      0.988300
# max         0.455000       0.695000      1.000000      0.999900
#
#        TextBlob_Polarity
# count       35266.000000
# mean            0.186714
# std             0.198521
# min            -0.700000
# 25%             0.046178
# 50%             0.172222
# 75%             0.309599
# max             1.000000

# %%
normalized_df=(df-df.mean())/df.std()
normalized_df.head()
# Out:
#   Cleaned Tweetcaptions Data Date Lemma  NegativeScore POS tagged  \
# 0                   NaN  NaN  NaN   NaN      -0.450346        NaN
# 1                   NaN  NaN  NaN   NaN      -0.675029        NaN
# 2                   NaN  NaN  NaN   NaN       0.085436        NaN
# 3                   NaN  NaN  NaN   NaN       0.811335        NaN
# 4                   NaN  NaN  NaN   NaN       1.468100        NaN
#
#   TextBlob_Analysis  TextBlob_Polarity Time  compound  neutralScore  \
# 0               NaN          -0.221735  NaN  0.603092      0.210229
# 1               NaN           0.067092  NaN  0.547251      1.184946
# 2               NaN          -0.342351  NaN  0.431218      0.172740
# 3               NaN          -0.220917  NaN  0.570822     -0.876956
# 4               NaN           0.133556  NaN -0.480630     -0.914445
#
#    positiveScore scores sentiment_type tweetcaption
# 0       0.111420    NaN            NaN          NaN
# 1      -0.684608    NaN            NaN          NaN
# 2      -0.226289    NaN            NaN          NaN
# 3       0.280275    NaN            NaN          NaN
# 4      -0.141861    NaN            NaN          NaN

# %%
df['nNegativeScore']=normalized_df['NegativeScore']
df['nneutralScore']=normalized_df['neutralScore']
df['npostiveScore']=normalized_df['positiveScore']
df['ncompound']=normalized_df['compound']
df['nTextBlob_Polarity']=normalized_df['TextBlob_Polarity']

# %%
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                           POS tagged  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  [(shree, a), (problem, n), (people, n), (probl...
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  \
# 0          0.159         0.800
# 1          0.093         0.878
# 2          0.131         0.797
# 3          0.173         0.713
# 4          0.138         0.710
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.059, 'neu': 0.742, 'pos': 0.199, 'co...    0.9747       POSITIVE
# 1  {'neg': 0.031, 'neu': 0.833, 'pos': 0.136, 'co...    0.9349       POSITIVE
# 2  {'neg': 0.123, 'neu': 0.689, 'pos': 0.188, 'co...    0.8522       POSITIVE
# 3  {'neg': 0.126, 'neu': 0.661, 'pos': 0.214, 'co...    0.9517       POSITIVE
# 4  {'neg': 0.213, 'neu': 0.586, 'pos': 0.201, 'co...    0.2023       POSITIVE
#
#    TextBlob_Polarity TextBlob_Analysis  nNegativeScore  nneutralScore  \
# 0           0.142695          Positive       -0.450346      -0.450346
# 1           0.200033          Positive       -0.675029      -0.675029
# 2           0.118750          Positive        0.085436       0.085436
# 3           0.142857          Positive        0.811335       0.811335
# 4           0.213228          Positive        1.468100       1.468100
#
#    npostiveScore  ncompound  nTextBlob_Polarity
# 0      -0.450346  -0.450346           -0.221735
# 1      -0.675029  -0.675029            0.067092
# 2       0.085436   0.085436           -0.342351
# 3       0.811335   0.811335           -0.220917
# 4       1.468100   1.468100            0.133556

# %%
df=df.drop(["POS tagged",'scores'],axis=1)

# %%
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound sentiment_type  TextBlob_Polarity  \
# 0          0.159         0.800    0.9747       POSITIVE           0.142695
# 1          0.093         0.878    0.9349       POSITIVE           0.200033
# 2          0.131         0.797    0.8522       POSITIVE           0.118750
# 3          0.173         0.713    0.9517       POSITIVE           0.142857
# 4          0.138         0.710    0.2023       POSITIVE           0.213228
#
#   TextBlob_Analysis  nNegativeScore  nneutralScore  npostiveScore  ncompound  \
# 0          Positive       -0.450346      -0.450346      -0.450346  -0.450346
# 1          Positive       -0.675029      -0.675029      -0.675029  -0.675029
# 2          Positive        0.085436       0.085436       0.085436   0.085436
# 3          Positive        0.811335       0.811335       0.811335   0.811335
# 4          Positive        1.468100       1.468100       1.468100   1.468100
#
#    nTextBlob_Polarity
# 0           -0.221735
# 1            0.067092
# 2           -0.342351
# 3           -0.220917
# 4            0.133556

# %%
df[df['sentiment_type'] =="NEUTRAL"].head() # checking neutral values
# Out:
#                           Data       Date      Time  \
# 116    DMKAgainstHindusCulture  7/14/2020  10:59:15
# 131    DMKAgainstHindusCulture  7/14/2020  11:59:15
# 901              ZTStreamParty  7/15/2020  12:59:18
# 970              ZTStreamParty  7/15/2020  14:59:17
# 1639              DronePrathap  7/16/2020  16:59:20
#
#                                            tweetcaption  \
# 116   Get ready dmk going to loss in 2021 DMKAgainst...
# 131   Get ready dmk going to loss in 2021 DMKAgainst...
# 901   Stream no 79 ZaraThehroBingo ZTStreamParty,Str...
# 970   Stream no 79 ZaraThehroBingo ZTStreamParty,Str...
# 1639  The book Our Moon has blood clots has been wri...
#
#                                   Cleaned Tweetcaptions  \
# 116   Get ready dmk going to loss in DMKAgainstHindu...
# 131   Get ready dmk going to loss in DMKAgainstHindu...
# 901   Stream no ZaraThehroBingo ZTStreamParty Stream...
# 970   Stream no ZaraThehroBingo ZTStreamParty Stream...
# 1639  The book Our Moon has blood clots has been wri...
#
#                                                   Lemma  NegativeScore  \
# 116     Get ready dmk go loss DMKAgainstHindusCultur...          0.087
# 131     Get ready dmk go loss DMKAgainstHindusCultur...          0.087
# 901     Stream ZaraThehroBingo ZTStreamParty Stream ...          0.415
# 970     Stream ZaraThehroBingo ZTStreamParty Stream ...          0.415
# 1639    book Moon blood clot write SKOOLPEDIA Online...          0.029
#
#       positiveScore  neutralScore  compound sentiment_type  TextBlob_Polarity  \
# 116           0.085         0.829      -0.0        NEUTRAL           0.215476
# 131           0.085         0.829      -0.0        NEUTRAL           0.215476
# 901           0.000         0.585       0.0        NEUTRAL           0.000000
# 970           0.000         0.585       0.0        NEUTRAL           0.000000
# 1639          0.066         0.905       0.0        NEUTRAL          -0.016667
#
#      TextBlob_Analysis  nNegativeScore  nneutralScore  npostiveScore  \
# 116           Positive        0.344686       0.344686       0.344686
# 131           Positive        0.344686       0.344686       0.344686
# 901            Neutral        6.013606       6.013606       6.013606
# 970            Neutral        6.013606       6.013606       6.013606
# 1639          Negative       -0.657745      -0.657745      -0.657745
#
#       ncompound  nTextBlob_Polarity
# 116    0.344686            0.144883
# 131    0.344686            0.144883
# 901    6.013606           -0.940525
# 970    6.013606           -0.940525
# 1639  -0.657745           -1.024479

# %%
cmax= df['compound'].max()
cmin= df['compound'].min()
df['nncompound'] = df.apply(lambda x:(x['compound']-cmin)/(cmax-cmin), axis=1) # normalizing 
df.head()

# %%
cmax= df['TextBlob_Polarity'].mean()
cmin= df['TextBlob_Polarity'].std()
df['nn1TextBlob_Polarity'] = df.apply(lambda x:(x['TextBlob_Polarity']-cmax)/(cmin), axis=1)
df.head()

# %%
cmax= df['compound'].std()
cmin= df['compound'].mean()
df['nn1compound'] = df.apply(lambda x:(x['nncompound']-cmin)/(cmax), axis=1) #standardizing
df.head()

# %% [markdown]
# I found out that normalizing the scores did not help so I dropped these columns

# %%
df=df.drop(["nncompound","nnTextBlob_Polarity","nn1TextBlob_Polarity","nn1compound"],axis=1) # dropping these as I found out that these were not useful

# %% [markdown]
# Creating a new score by taking the average of scores of VADER and TextBlob

# %%
df['average0'] = df.apply(lambda x:(x['compound']+x['TextBlob_Polarity'])/(2), axis=1) # finding average
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound sentiment_type  TextBlob_Polarity  \
# 0          0.159         0.800    0.9747       POSITIVE           0.142695
# 1          0.093         0.878    0.9349       POSITIVE           0.200033
# 2          0.131         0.797    0.8522       POSITIVE           0.118750
# 3          0.173         0.713    0.9517       POSITIVE           0.142857
# 4          0.138         0.710    0.2023       POSITIVE           0.213228
#
#   TextBlob_Analysis  nNegativeScore  nneutralScore  npostiveScore  ncompound  \
# 0          Positive       -0.450346       0.210229       0.111420   0.603092
# 1          Positive       -0.675029       1.184946      -0.684608   0.547251
# 2          Positive        0.085436       0.172740      -0.226289   0.431218
# 3          Positive        0.811335      -0.876956       0.280275   0.570822
# 4          Positive        1.468100      -0.914445      -0.141861  -0.480630
#
#    nTextBlob_Polarity  average0
# 0           -0.221735  0.558697
# 1            0.067092  0.567466
# 2           -0.342351  0.485475
# 3           -0.220917  0.547279
# 4            0.133556  0.207764

# %%
def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"
df["new_score"] = df["average0"].apply(getAnalysis ) #Analysing the new score
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound sentiment_type  TextBlob_Polarity  \
# 0          0.159         0.800    0.9747       POSITIVE           0.142695
# 1          0.093         0.878    0.9349       POSITIVE           0.200033
# 2          0.131         0.797    0.8522       POSITIVE           0.118750
# 3          0.173         0.713    0.9517       POSITIVE           0.142857
# 4          0.138         0.710    0.2023       POSITIVE           0.213228
#
#   TextBlob_Analysis  nNegativeScore  nneutralScore  npostiveScore  ncompound  \
# 0          Positive       -0.450346       0.210229       0.111420   0.603092
# 1          Positive       -0.675029       1.184946      -0.684608   0.547251
# 2          Positive        0.085436       0.172740      -0.226289   0.431218
# 3          Positive        0.811335      -0.876956       0.280275   0.570822
# 4          Positive        1.468100      -0.914445      -0.141861  -0.480630
#
#    nTextBlob_Polarity  average0 new_score
# 0           -0.221735  0.558697  Positive
# 1            0.067092  0.567466  Positive
# 2           -0.342351  0.485475  Positive
# 3           -0.220917  0.547279  Positive
# 4            0.133556  0.207764  Positive

# %% [markdown]
# Comparing the analysis of new score with the two models

# %%
print(df["new_score"].value_counts())
print(df['TextBlob_Analysis'].value_counts())
print(df['sentiment_type'].value_counts())
# Out:
# Positive    27858
# Negative     7330
# Neutral        78
# Name: new_score, dtype: int64
# Positive    29343
# Negative     5675
# Neutral       248
# Name: TextBlob_Analysis, dtype: int64
# POSITIVE    27652
# NEGATIVE     7468
# NEUTRAL       146
# Name: sentiment_type, dtype: int64

# %% [markdown]
# #### SentiWordNet

# %% [markdown]
# Adding Parts of Speech Column(POS)

# %%
# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV} 
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist

df['POS tagged'] = df['Cleaned Tweetcaptions'].apply(token_stop_pos)
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound  ... TextBlob_Polarity  \
# 0          0.159         0.800    0.9747  ...          0.142695
# 1          0.093         0.878    0.9349  ...          0.200033
# 2          0.131         0.797    0.8522  ...          0.118750
# 3          0.173         0.713    0.9517  ...          0.142857
# 4          0.138         0.710    0.2023  ...          0.213228
#
#    TextBlob_Analysis nNegativeScore  nneutralScore  npostiveScore  ncompound  \
# 0           Positive      -0.450346       0.210229       0.111420   0.603092
# 1           Positive      -0.675029       1.184946      -0.684608   0.547251
# 2           Positive       0.085436       0.172740      -0.226289   0.431218
# 3           Positive       0.811335      -0.876956       0.280275   0.570822
# 4           Positive       1.468100      -0.914445      -0.141861  -0.480630
#
#    nTextBlob_Polarity  average0  new_score  \
# 0           -0.221735  0.558697   Positive
# 1            0.067092  0.567466   Positive
# 2           -0.342351  0.485475   Positive
# 3           -0.220917  0.547279   Positive
# 4            0.133556  0.207764   Positive
#
#                                           POS tagged
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  [(shree, a), (problem, n), (people, n), (probl...
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...
#
# [5 rows x 21 columns]

# %% [markdown]
# Applying SentiWordNet and modifying it to get the score as well

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
def sentiwordnetanalysis(pos_data):
    sentiment = 0
    tokens_count = 0
    for word, pos in pos_data:
        if not pos:
            continue
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        if not lemma:
            continue
        synsets = wordnet.synsets(lemma, pos=pos)
        if not synsets:
            continue
        # Take the first sense, the most common
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        sentiment += swn_synset.pos_score() - swn_synset.neg_score()
        tokens_count += 1
        # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
        if not tokens_count:
            return 0
        if sentiment>0:
            return "Positive"
        if sentiment==0:
            return "Neutral"
        else:
            return "Negative"

df['SWN analysis'] = df['POS tagged'].apply(sentiwordnetanalysis)
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound  ... TextBlob_Analysis  \
# 0          0.159         0.800    0.9747  ...          Positive
# 1          0.093         0.878    0.9349  ...          Positive
# 2          0.131         0.797    0.8522  ...          Positive
# 3          0.173         0.713    0.9517  ...          Positive
# 4          0.138         0.710    0.2023  ...          Positive
#
#    nNegativeScore nneutralScore  npostiveScore  ncompound  nTextBlob_Polarity  \
# 0       -0.450346      0.210229       0.111420   0.603092           -0.221735
# 1       -0.675029      1.184946      -0.684608   0.547251            0.067092
# 2        0.085436      0.172740      -0.226289   0.431218           -0.342351
# 3        0.811335     -0.876956       0.280275   0.570822           -0.220917
# 4        1.468100     -0.914445      -0.141861  -0.480630            0.133556
#
#    average0  new_score                                         POS tagged  \
# 0  0.558697   Positive  [(Love, v), (vacation, n), (vibes, n), (amazin...
# 1  0.567466   Positive  [(Best, n), (Camera, n), (Smartphone, n), (k, ...
# 2  0.485475   Positive  [(shree, a), (problem, n), (people, n), (probl...
# 3  0.547279   Positive  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...
# 4  0.207764   Positive  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...
#
#   SWN analysis
# 0     Positive
# 1     Positive
# 2     Negative
# 3      Neutral
# 4      Neutral
#
# [5 rows x 22 columns]

# %%
df['SWN analysis'].value_counts()
# Out:
# Neutral     23928
# Positive     8337
# Negative     2991
# Name: SWN analysis, dtype: int64

# %% [markdown]
# Changing the function to output sentiment score

# %%
def sentiwordnetscore(pos_data):
    sentiment = 0
    tokens_count = 0
    for word, pos in pos_data:
        if not pos:
            continue
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        if not lemma:
            continue
        synsets = wordnet.synsets(lemma, pos=pos)
        if not synsets:
            continue
        # Take the first sense, the most common
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        sentiment += swn_synset.pos_score() - swn_synset.neg_score()
        tokens_count += 1
        return sentiment;
df['SWN_score'] = df['POS tagged'].apply(sentiwordnetscore)
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound  ... nNegativeScore  nneutralScore  \
# 0          0.159         0.800    0.9747  ...      -0.450346       0.210229
# 1          0.093         0.878    0.9349  ...      -0.675029       1.184946
# 2          0.131         0.797    0.8522  ...       0.085436       0.172740
# 3          0.173         0.713    0.9517  ...       0.811335      -0.876956
# 4          0.138         0.710    0.2023  ...       1.468100      -0.914445
#
#   npostiveScore  ncompound  nTextBlob_Polarity  average0  new_score  \
# 0      0.111420   0.603092           -0.221735  0.558697   Positive
# 1     -0.684608   0.547251            0.067092  0.567466   Positive
# 2     -0.226289   0.431218           -0.342351  0.485475   Positive
# 3      0.280275   0.570822           -0.220917  0.547279   Positive
# 4     -0.141861  -0.480630            0.133556  0.207764   Positive
#
#                                           POS tagged  SWN analysis SWN_score
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...      Positive     0.500
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...      Positive     0.250
# 2  [(shree, a), (problem, n), (people, n), (probl...      Negative    -0.625
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...       Neutral     0.000
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...       Neutral     0.000
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Final score

# %% [markdown]
# Finding the final score by taking the average of the scores of VADER, TextBlob and SentiWordNet as it will give more a generalized prediction giving it a representation of all the three models.

# %%
df['average1'] = df.apply(lambda x:(x['compound']+x['TextBlob_Polarity']+x['SWN_score'])/(3), axis=1) #Finding the average score
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound  ... nneutralScore  npostiveScore  \
# 0          0.159         0.800    0.9747  ...      0.210229       0.111420
# 1          0.093         0.878    0.9349  ...      1.184946      -0.684608
# 2          0.131         0.797    0.8522  ...      0.172740      -0.226289
# 3          0.173         0.713    0.9517  ...     -0.876956       0.280275
# 4          0.138         0.710    0.2023  ...     -0.914445      -0.141861
#
#   ncompound  nTextBlob_Polarity  average0  new_score  \
# 0  0.603092           -0.221735  0.558697   Positive
# 1  0.547251            0.067092  0.567466   Positive
# 2  0.431218           -0.342351  0.485475   Positive
# 3  0.570822           -0.220917  0.547279   Positive
# 4 -0.480630            0.133556  0.207764   Positive
#
#                                           POS tagged  SWN analysis  SWN_score  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...      Positive      0.500
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...      Positive      0.250
# 2  [(shree, a), (problem, n), (people, n), (probl...      Negative     -0.625
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...       Neutral      0.000
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...       Neutral      0.000
#
#    average1
# 0  0.539132
# 1  0.461644
# 2  0.115317
# 3  0.364852
# 4  0.138509
#
# [5 rows x 24 columns]

# %%
df["newest_score"] = df["average1"].apply(getAnalysis ) # Adding the analysis
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound  ... npostiveScore  ncompound  \
# 0          0.159         0.800    0.9747  ...      0.111420   0.603092
# 1          0.093         0.878    0.9349  ...     -0.684608   0.547251
# 2          0.131         0.797    0.8522  ...     -0.226289   0.431218
# 3          0.173         0.713    0.9517  ...      0.280275   0.570822
# 4          0.138         0.710    0.2023  ...     -0.141861  -0.480630
#
#   nTextBlob_Polarity  average0  new_score  \
# 0          -0.221735  0.558697   Positive
# 1           0.067092  0.567466   Positive
# 2          -0.342351  0.485475   Positive
# 3          -0.220917  0.547279   Positive
# 4           0.133556  0.207764   Positive
#
#                                           POS tagged  SWN analysis  SWN_score  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...      Positive      0.500
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...      Positive      0.250
# 2  [(shree, a), (problem, n), (people, n), (probl...      Negative     -0.625
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...       Neutral      0.000
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...       Neutral      0.000
#
#    average1 newest_score
# 0  0.539132     Positive
# 1  0.461644     Positive
# 2  0.115317     Positive
# 3  0.364852     Positive
# 4  0.138509     Positive
#
# [5 rows x 25 columns]

# %% [markdown]
# Comparing the analysis of all the models

# %%
print(df["new_score"].value_counts())
print(df['TextBlob_Analysis'].value_counts())
print(df['sentiment_type'].value_counts())
print(df['SWN analysis'].value_counts())
print(df['newest_score'].value_counts())
# Out:
# Positive    27858
# Negative     7330
# Neutral        78
# Name: new_score, dtype: int64
# Positive    29343
# Negative     5675
# Neutral       248
# Name: TextBlob_Analysis, dtype: int64
# POSITIVE    27652
# NEGATIVE     7468
# NEUTRAL       146
# Name: sentiment_type, dtype: int64
# Neutral     23928
# Positive     8337
# Negative     2991
# Name: SWN analysis, dtype: int64
# Positive    27851
# Negative     7347
# Neutral        68
# Name: newest_score, dtype: int64

# %%
df.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                Cleaned Tweetcaptions  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under k Please vote and...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound  ... npostiveScore  ncompound  \
# 0          0.159         0.800    0.9747  ...      0.111420   0.603092
# 1          0.093         0.878    0.9349  ...     -0.684608   0.547251
# 2          0.131         0.797    0.8522  ...     -0.226289   0.431218
# 3          0.173         0.713    0.9517  ...      0.280275   0.570822
# 4          0.138         0.710    0.2023  ...     -0.141861  -0.480630
#
#   nTextBlob_Polarity  average0  new_score  \
# 0          -0.221735  0.558697   Positive
# 1           0.067092  0.567466   Positive
# 2          -0.342351  0.485475   Positive
# 3          -0.220917  0.547279   Positive
# 4           0.133556  0.207764   Positive
#
#                                           POS tagged  SWN analysis  SWN_score  \
# 0  [(Love, v), (vacation, n), (vibes, n), (amazin...      Positive      0.500
# 1  [(Best, n), (Camera, n), (Smartphone, n), (k, ...      Positive      0.250
# 2  [(shree, a), (problem, n), (people, n), (probl...      Negative     -0.625
# 3  [(Rhea, n), (Chakraborty, n), (Heartbreaking, ...       Neutral      0.000
# 4  [(stand, v), (Sunita, n), (Yadav, n), (Stop, n...       Neutral      0.000
#
#    average1 newest_score
# 0  0.539132     Positive
# 1  0.461644     Positive
# 2  0.115317     Positive
# 3  0.364852     Positive
# 4  0.138509     Positive
#
# [5 rows x 25 columns]

# %% [markdown]
# Cleaning the dataset by removing unwanted columns and rearranging and renaming the useful ones

# %%
df_final=df.drop(["Cleaned Tweetcaptions","nNegativeScore","npostiveScore","ncompound","nTextBlob_Polarity","nneutralScore","POS tagged","new_score","average0"],axis=1)
df_final.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  NegativeScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...          0.041
# 1    Best Camera Smartphone k Please vote help re...          0.028
# 2    shree problem people problem Stupid Communis...          0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...          0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...          0.152
#
#    positiveScore  neutralScore  compound sentiment_type  TextBlob_Polarity  \
# 0          0.159         0.800    0.9747       POSITIVE           0.142695
# 1          0.093         0.878    0.9349       POSITIVE           0.200033
# 2          0.131         0.797    0.8522       POSITIVE           0.118750
# 3          0.173         0.713    0.9517       POSITIVE           0.142857
# 4          0.138         0.710    0.2023       POSITIVE           0.213228
#
#   TextBlob_Analysis SWN analysis  SWN_score  average1 newest_score
# 0          Positive     Positive      0.500  0.539132     Positive
# 1          Positive     Positive      0.250  0.461644     Positive
# 2          Positive     Negative     -0.625  0.115317     Positive
# 3          Positive      Neutral      0.000  0.364852     Positive
# 4          Positive      Neutral      0.000  0.138509     Positive

# %%
df_final.rename(columns={'NegativeScore': 'Vader_negScore', 'positiveScore': 'Vader_posScore', 'neutralScore': 'Vader_neuScore', 'compound': 'Vader_compoundScore', 'sentiment_type': 'Vader_analysis', 'average1': 'newScore', 'newest_score': 'combinedAnalysis'}, inplace=True)
df_final.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  Vader_negScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...           0.041
# 1    Best Camera Smartphone k Please vote help re...           0.028
# 2    shree problem people problem Stupid Communis...           0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...           0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...           0.152
#
#    Vader_posScore  Vader_neuScore  Vader_compoundScore Vader_analysis  \
# 0           0.159           0.800               0.9747       POSITIVE
# 1           0.093           0.878               0.9349       POSITIVE
# 2           0.131           0.797               0.8522       POSITIVE
# 3           0.173           0.713               0.9517       POSITIVE
# 4           0.138           0.710               0.2023       POSITIVE
#
#    TextBlob_Polarity TextBlob_Analysis SWN analysis  SWN_score  newScore  \
# 0           0.142695          Positive     Positive      0.500  0.539132
# 1           0.200033          Positive     Positive      0.250  0.461644
# 2           0.118750          Positive     Negative     -0.625  0.115317
# 3           0.142857          Positive      Neutral      0.000  0.364852
# 4           0.213228          Positive      Neutral      0.000  0.138509
#
#   combinedAnalysis
# 0         Positive
# 1         Positive
# 2         Positive
# 3         Positive
# 4         Positive

# %%
oldcols=df_final.columns
oldcols
# Out:
# Index(['Data', 'Date', 'Time', 'tweetcaption', 'Lemma', 'Vader_negScore',
#        'Vader_posScore', 'Vader_neuScore', 'Vader_compoundScore',
#        'Vader_analysis', 'TextBlob_Polarity', 'TextBlob_Analysis',
#        'SWN analysis', 'SWN_score', 'newScore', 'combinedAnalysis'],
#       dtype='object')

# %%
newcols=['Data', 'Date', 'Time', 'tweetcaption', 'Lemma', 'Vader_negScore',
       'Vader_posScore', 'Vader_neuScore', 'Vader_compoundScore',
       'Vader_analysis', 'TextBlob_Polarity', 'TextBlob_Analysis',
       'SWN_score','SWN analysis', 'newScore', 'combinedAnalysis']
df_final = df_final.reindex(columns=newcols)
df_final.head()
# Out:
#                           Data       Date     Time  \
# 0                 tuesdayvibes  7/14/2020  7:00:21
# 1                    realmeC11  7/14/2020  7:00:21
# 2                  KPSharmaOli  7/14/2020  7:00:21
# 3              RheaChakraborty  7/14/2020  7:00:21
# 4   Stop_Transfer_Sunita_Yadav  7/14/2020  7:00:21
#
#                                         tweetcaption  \
# 0  Love it here vacation vibes amazing beautiful ...
# 1  Best Camera Smartphone under 20k Please vote a...
# 2  shree Why should we have a problem with the pe...
# 3  Rhea Chakraborty s Heartbreaking Post On Susha...
# 4  We stand for Sunita Yadav Stop the Transfer Wh...
#
#                                                Lemma  Vader_negScore  \
# 0    Love vacation vibe amaze beautiful cabo mexi...           0.041
# 1    Best Camera Smartphone k Please vote help re...           0.028
# 2    shree problem people problem Stupid Communis...           0.072
# 3    Rhea Chakraborty Heartbreaking Post Sushant ...           0.114
# 4    stand Sunita Yadav Stop Transfer woman empow...           0.152
#
#    Vader_posScore  Vader_neuScore  Vader_compoundScore Vader_analysis  \
# 0           0.159           0.800               0.9747       POSITIVE
# 1           0.093           0.878               0.9349       POSITIVE
# 2           0.131           0.797               0.8522       POSITIVE
# 3           0.173           0.713               0.9517       POSITIVE
# 4           0.138           0.710               0.2023       POSITIVE
#
#    TextBlob_Polarity TextBlob_Analysis  SWN_score SWN analysis  newScore  \
# 0           0.142695          Positive      0.500     Positive  0.539132
# 1           0.200033          Positive      0.250     Positive  0.461644
# 2           0.118750          Positive     -0.625     Negative  0.115317
# 3           0.142857          Positive      0.000      Neutral  0.364852
# 4           0.213228          Positive      0.000      Neutral  0.138509
#
#   combinedAnalysis
# 0         Positive
# 1         Positive
# 2         Positive
# 3         Positive
# 4         Positive

# %%
print(df_final['TextBlob_Analysis'].value_counts())
print(df_final['Vader_analysis'].value_counts())
print(df_final['SWN analysis'].value_counts())
print(df_final['combinedAnalysis'].value_counts())
# Out:
# Positive    29343
# Negative     5675
# Neutral       248
# Name: TextBlob_Analysis, dtype: int64
# POSITIVE    27652
# NEGATIVE     7468
# NEUTRAL       146
# Name: Vader_analysis, dtype: int64
# Neutral     23928
# Positive     8337
# Negative     2991
# Name: SWN analysis, dtype: int64
# Positive    27851
# Negative     7347
# Neutral        68
# Name: combinedAnalysis, dtype: int64
